# %%
name = "Zabeena Sherzoie"
social_issue = "Education access and equality"
data_Sources = {
    "UNESCO Institute for Statistics",
    "World Bank Education Data",
    "UNICEF Education Reports",
    "Demographic and Health Surveys (DHS)",
    "National education ministry databases",
    "Academic research on education inequality"
}
key_metrics= {
        "global_primary_out_of_school_children_millions": 64,
        "global_secondary_out_of_school_children_millions": 120,
        "literacy_rate_low_income_countries_percent": 65,
        "student_teacher_ratio_low_income_regions": 40
    }

print("Hello, World!")
print(f"My name is {name}.")
print(f"The social issue I am interested in is: {social_issue}")
print("\n Some data sources I might use to learn more about this issue include:")
for source in data_Sources:
    print(f"- {source}")
print("\n Some key metrics related to this issue include:")
for metric, value in key_metrics.items():
    print(f"- {metric.replace('_', ' ').capitalize()}: {value}")
# Out:
# Hello, World!
# My name is Zabeena Sherzoie.
# The social issue I am interested in is: Education access and equality
#
#  Some data sources I might use to learn more about this issue include:
# - World Bank Education Data
# - Demographic and Health Surveys (DHS)
# - Academic research on education inequality
# - National education ministry databases
# - UNESCO Institute for Statistics
# - UNICEF Education Reports
#
#  Some key metrics related to this issue include:
# - Global primary out of school children millions: 64
# - Global secondary out of school children millions: 120
# - Literacy rate low income countries percent: 65
# - Student teacher ratio low income regions: 40
